# %%
from main import PororoOcr

# %% [markdown]
# 최초에 한번은 Model을 다운로드 합니다. 경로는 Windows의 경우 ```C:/pororo/misc```이고 Mac OS의 경우는 ```~/.pororo/misc/``` 입니다.

# %%
ocr = PororoOcr()

# %% [markdown]
# 현재 지원 가능하는 언어는 영어와 한국어 입니다.

# %%
ocr.get_available_langs()
# Out:
# ['en', 'ko']

# %%
ocr.get_available_models()
# Out:
# {'en': ['brainocr'], 'ko': ['brainocr']}

# %% [markdown]
# **Examples**
# ```python
# ocr = Pororo(task='ocr', lang='ko')
# ocr(IMAGE_PATH)
# ```

# %%
img_path = 'C:/code/bank_statement/kookmin.png'

# %%
ocr.run_ocr(img_path, debug=True)
# Out:
# ['| 99% 1:41',
#  '거래내역조회',
#  '2025.02.28 20:22:48',
#  '뚜레쥬르강남직영점',
#  '출금 19,800 원 잔액 781,250 원',
#  '2025.02.28 20:05:37',
#  '무인양품 (주) 강남점',
#  '출금 4,900 원 잔액 801,050 원',
#  '2025.02.28 19:27:49',
#  '(주) 빅바이트컴퍼니',
#  '출금 29,100 원 잔액 805,950 원',
#  '2025.02.28 17:06:09',
#  'Degica',
#  '출금 9,000 원 잔액 835,050 원',
#  '2025.02.27 14:10:53',
#  '이마트에브리데이',
#  '출금 42,610 잔액 844,056원',
#  '75 07 25 71.01-72']

# %%
ocr.get_ocr_result()
# Out:
# {'description': ['| 99% 1:41',
#   '거래내역조회',
#   '2025.02.28 20:22:48',
#   '뚜레쥬르강남직영점',
#   '출금 19,800 원 잔액 781,250 원',
#   '2025.02.28 20:05:37',
#   '무인양품 (주) 강남점',
#   '출금 4,900 원 잔액 801,050 원',
#   '2025.02.28 19:27:49',
#   '(주) 빅바이트컴퍼니',
#   '출금 29,100 원 잔액 805,950 원',
#   '2025.02.28 17:06:09',
#   'Degica',
#   '출금 9,000 원 잔액 835,050 원',
#   '2025.02.27 14:10:53',
#   '이마트에브리데이',
#   '출금 42,610 잔액 844,056원',
#   '75 07 25 71.01-72'],
#  'bounding_poly': [{'description': '| 99% 1:41',
#    'vertices': [{'x': 839, 'y': 29},
#     {'x': 1039, 'y': 29},
#     {'x': 1039, 'y': 69},
#     {'x': 839, 'y': 69}]},
#   {'description': '거래내역조회',
#    'vertices': [{'x': 133, 'y': 107},
#     {'x': 393, 'y': 107},
#     {'x': 393, 'y': 171},
#     {'x': 133, 'y': 171}]},
#   {'description': '2025.02.28 20:22:48',
#    'vertices': [{'x': 59, 'y': 247},
#     {'x': 411, 'y': 247},
#     {'x': 411, 'y': 289},
#     {'x': 59, 'y': 289}]},
#   {'description': '뚜레쥬르강남직영점',
#    'vertices': [{'x': 58, 'y': 332},
#     {'x': 402, 'y': 332},
#     {'x': 402, 'y': 388},
#     {'x': 58, 'y': 388}]},
#   {'description': '출금 19,800 원 잔액 781,250 원',
#    'vertices': [{'x': 757, 'y': 419},
#     {'x': 1022, 'y': 419},
#     {'x': 1022, 'y': 542},
#     {'x': 757, 'y': 542}]},
#   {'description': '2025.02.28 20:05:37',
#    'vertices': [{'x': 58, 'y': 653},
#     {'x': 410, 'y': 653},
#     {'x': 410, 'y': 701},
#     {'x': 58, 'y': 701}]},
#   {'description': '무인양품 (주) 강남점',
#    'vertices': [{'x': 58, 'y': 742},
#     {'x': 438, 'y': 742},
#     {'x': 438, 'y': 798},
#     {'x': 58, 'y': 798}]},
#   {'description': '출금 4,900 원 잔액 801,050 원',
#    'vertices': [{'x': 770, 'y': 832},
#     {'x': 1022, 'y': 832},
#     {'x': 1022, 'y': 950},
#     {'x': 770, 'y': 950}]},
#   {'description': '2025.02.28 19:27:49',
#    'vertices': [{'x': 59, 'y': 1065},
#     {'x': 411, 'y': 1065},
#     {'x': 411, 'y': 1107},
#     {'x': 59, 'y': 1107}]},
#   {'description': '(주) 빅바이트컴퍼니',
#    'vertices': [{'x': 84, 'y': 1149},
#     {'x': 437, 'y': 1149},
#     {'x': 437, 'y': 1205},
#     {'x': 84, 'y': 1205}]},
#   {'description': '출금 29,100 원 잔액 805,950 원',
#    'vertices': [{'x': 760, 'y': 1240},
#     {'x': 1021, 'y': 1240},
#     {'x': 1021, 'y': 1357},
#     {'x': 760, 'y': 1357}]},
#   {'description': '2025.02.28 17:06:09',
#    'vertices': [{'x': 59, 'y': 1473},
#     {'x': 411, 'y': 1473},
#     {'x': 411, 'y': 1515},
#     {'x': 59, 'y': 1515}]},
#   {'description': 'Degica',
#    'vertices': [{'x': 64, 'y': 1560},
#     {'x': 284, 'y': 1560},
#     {'x': 284, 'y': 1616},
#     {'x': 64, 'y': 1616}]},
#   {'description': '출금 9,000 원 잔액 835,050 원',
#    'vertices': [{'x': 768, 'y': 1650},
#     {'x': 1022, 'y': 1650},
#     {'x': 1022, 'y': 1768},
#     {'x': 768, 'y': 1768}]},
#   {'description': '2025.02.27 14:10:53',
#    'vertices': [{'x': 59, 'y': 1883},
#     {'x': 411, 'y': 1883},
#     {'x': 411, 'y': 1925},
#     {'x': 59, 'y': 1925}]},
#   {'description': '이마트에브리데이',
#    'vertices': [{'x': 60, 'y': 1968},
#     {'x': 365, 'y': 1968},
#     {'x': 365, 'y': 2024},
#     {'x': 60, 'y': 2024}]},
#   {'description': '출금 42,610 잔액 844,056원',
#    'vertices': [{'x': 760, 'y': 2058},
#     {'x': 1021, 'y': 2058},
#     {'x': 1021, 'y': 2178},
#     {'x': 760, 'y': 2178}]},
#   {'description': '75 07 25 71.01-72',
#    'vertices': [{'x': 106, 'y': 2294},
#     {'x': 406, 'y': 2294},
#     {'x': 406, 'y': 2316},
#     {'x': 106, 'y': 2316}]}]}
